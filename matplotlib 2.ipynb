# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
x=np.linspace(3,2,5)
x
# Out:
# array([3.  , 2.75, 2.5 , 2.25, 2.  ])

# %%
y=x**2
y
# Out:
# array([9.    , 7.5625, 6.25  , 5.0625, 4.    ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel("values of x")
plt.ylabel("values of Y")
plt.title("graph of y$=x^2$")
plt.plot(x,y)
plt.show()

# %%
x1=np.linspace(-np.pi,np.pi,25)
x1
# Out:
# array([-3.14159265, -2.87979327, -2.61799388, -2.35619449, -2.0943951 ,
#        -1.83259571, -1.57079633, -1.30899694, -1.04719755, -0.78539816,
#        -0.52359878, -0.26179939,  0.        ,  0.26179939,  0.52359878,
#         0.78539816,  1.04719755,  1.30899694,  1.57079633,  1.83259571,
#         2.0943951 ,  2.35619449,  2.61799388,  2.87979327,  3.14159265])

# %%
x2=np.linspace(-np.pi,np.pi,25)
x2
# Out:
# array([-3.14159265, -2.87979327, -2.61799388, -2.35619449, -2.0943951 ,
#        -1.83259571, -1.57079633, -1.30899694, -1.04719755, -0.78539816,
#        -0.52359878, -0.26179939,  0.        ,  0.26179939,  0.52359878,
#         0.78539816,  1.04719755,  1.30899694,  1.57079633,  1.83259571,
#         2.0943951 ,  2.35619449,  2.61799388,  2.87979327,  3.14159265])

# %%
plt.plot(x1,y1)
plt.show()

# %%
y1=np.cos(x1)
y2=np.sin(x2)
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.show()

# %%
plt.figure(figsize=(10,6),dpi=80)
plt.plot(x1,y1,color="Green",lw=3.5)
plt.plot(x2,y2,color="red",lw=3.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1217578279> in <cell line: 0>()
#       1 plt.figure(figsize=(10,6),dpi=80)
#       2 plt.plot(x1,y1,color="Green",lw=3.5)
# ----> 3 plt.plot(x2,y2,color="red",lw=3.5)
#       4 plt.show()
#
# NameError: name 'x2' is not defined

# %%
plt.figure(figsize(8,9),dpi=85)
plt.plot(x1,)
